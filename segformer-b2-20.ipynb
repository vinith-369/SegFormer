# %%
import sys
# Add the parent directory (SEGFORMER-TF-MAIN) to the system path
sys.path.append('../')

# %%
#pip install matplotlib

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import math
import glob

#SegFormer
from models import SegFormer_B2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# ...

# %%
# img = glob.glob('/kaggle/input/cityscapes/Cityspaces/images/train/*/*.png') # tf.io.glob.glob
# label = glob.glob('/kaggle/input/cityscapes/Cityspaces/gtFine/train/*/*_gtFine_labelIds.png')
# img_names = [path.split('/train/')[1].split('_leftImg8bit.png')[0] for path in img]
# label = ['/kaggle/input/cityscapes/Cityspaces/gtFine/train/' + name + '_gtFine_labelIds.png' for name in img_names]

# val_img = glob.glob('/kaggle/input/cityscapes/Cityspaces/images/val/*/*.png') # tf.io.glob.glob
# val_label = glob.glob('/kaggle/input/cityscapes/Cityspaces/gtFine/val/*/*_gtFine_labelIds.png')
# img_names = [path.split('/val/')[1].split('_leftImg8bit.png')[0] for path in val_img]
# val_label = ['/kaggle/input/cityscapes/Cityspaces/gtFine/val/' + name + '_gtFine_labelIds.png' for name in img_names]

# %%
img = glob.glob('/Users/vinithlankireddy/Projects/LLMs/Segfromer/SegFormer-tf-main/Cityspaces/images/train/*/*.png') # tf.io.glob.glob
label = glob.glob('/Users/vinithlankireddy/Projects/LLMs/Segfromer/SegFormer-tf-main/Cityspaces/gtFine/train*/*_gtFine_labelIds.png')
img_names = [path.split('/train/')[1].split('_leftImg8bit.png')[0] for path in img]
label = ['/Users/vinithlankireddy/Projects/LLMs/Segfromer/SegFormer-tf-main/Cityspaces/gtFine/train/' + name + '_gtFine_labelIds.png' for name in img_names]

val_img = glob.glob('/Users/vinithlankireddy/Projects/LLMs/Segfromer/SegFormer-tf-main/Cityspaces/images/val/*/*.png') # tf.io.glob.glob
val_label = glob.glob('/Users/vinithlankireddy/Projects/LLMs/Segfromer/SegFormer-tf-main/Cityspaces/gtFine/val/*/*_gtFine_labelIds.png')
img_names = [path.split('/val/')[1].split('_leftImg8bit.png')[0] for path in val_img]
val_label = ['/Users/vinithlankireddy/Projects/LLMs/Segfromer/SegFormer-tf-main/Cityspaces/gtFine/val/' + name + '_gtFine_labelIds.png' for name in img_names]

# %%
# img = glob.glob('C:\\Users\\chaitanya-stu\\Downloads\\segfromer-20251101T173739Z-1-001\\segfromer\\Cityspaces\\images\\train\\*\\*.png')
# label = glob.glob('C:\\Users\\chaitanya-stu\\Downloads\\segfromer-20251101T173739Z-1-001\\segfromer\\Cityspaces\\gtFine\\train\\*\\*_gtFine_labelIds.png')

# img_names = [path.split('\\train\\')[1].split('_leftImg8bit.png')[0] for path in img]
# label = ['C:\\Users\\chaitanya-stu\\Downloads\\segfromer-20251101T173739Z-1-001\\segfromer\\Cityspaces\\gtFine\\train\\' + name + '_gtFine_labelIds.png' for name in img_names]


# val_img = glob.glob('C:\\Users\\chaitanya-stu\\Downloads\\segfromer-20251101T173739Z-1-001\\segfromer\\Cityspaces\\images\\val\\*\\*.png')
# val_label = glob.glob('C:\\Users\\chaitanya-stu\\Downloads\\segfromer-20251101T173739Z-1-001\\segfromer\\Cityspaces\\gtFine\\val\\*\\*_gtFine_labelIds.png')

# img_names = [path.split('\\val\\')[1].split('_leftImg8bit.png')[0] for path in val_img]
# val_label = ['C:\\Users\\chaitanya-stu\\Downloads\\segfromer-20251101T173739Z-1-001\\segfromer\\Cityspaces\\gtFine\\val\\' + name + '_gtFine_labelIds.png' for name in img_names]

# %%
train_ds = tf.data.Dataset.from_tensor_slices((img, label))
val_ds = tf.data.Dataset.from_tensor_slices((val_img, val_label))

# %%
def read_image(img):
    img = tf.io.read_file(img)
    img = tf.image.decode_png(img, channels=3)
    img = tf.image.resize(img, [256,256])
    return img
    
def read_mask(img):
    img = tf.io.read_file(img)
    img = tf.image.decode_png(img, channels=1)
    img = tf.image.resize(img, [256,256])
    return img

def rand_crop(img, mask):
    concat_img = tf.concat([img, mask], axis=-1)
    concat_img = tf.image.resize(concat_img, [280, 560], method=tf.image.ResizeMethod.NEAREST_NEIGHBOR)
    crop_img = tf.image.random_crop(concat_img, [256, 256, 4])
    return crop_img[:, :, :3], crop_img[:, :, 3:]

def norm(image, mask):
    image = tf.cast(image, tf.float32)/127.5-1
    mask = tf.cast(mask, tf.int32)
    return image, mask

# %%
def load_img_train(img, mask):
    image = read_image(img)
    mask = read_mask(mask)
    image, mask = rand_crop(image, mask)
    return norm(image, mask)

def load_img_val(img, mask):
    image = read_image(img)
    mask = read_mask(mask)
    return norm(image, mask)

# %%
train_ds = train_ds.map(load_img_train, num_parallel_calls=tf.data.AUTOTUNE)
train_ds = train_ds.repeat()
train_ds = train_ds.batch(8)
train_ds = train_ds.prefetch(tf.data.AUTOTUNE)

val_ds = val_ds.map(load_img_val, num_parallel_calls=tf.data.AUTOTUNE)
val_ds = val_ds.batch(8)
val_ds = val_ds.cache()
val_ds = val_ds.prefetch(tf.data.AUTOTUNE)

# %%
def plot_images(img_batch, mask_batch):
    batch_size = img_batch.shape[0]
    num_cols = int(math.sqrt(batch_size))
    num_rows = math.ceil(batch_size / num_cols)
    
    fig, axes = plt.subplots(num_rows, 2*num_cols, figsize=(15, 15), gridspec_kw={'hspace': 0.005})
    for i in range(batch_size):
        row = i // num_cols
        col = i % num_cols
        
        axes[row, 2*col].imshow((img_batch[i]+1) / 2)
        axes[row, 2*col].axis('off')
        axes[row, 2*col+1].imshow(mask_batch[i])
        axes[row, 2*col+1].axis('off')
    
    plt.show()

# %%
for img_batch, mask_batch in train_ds.take(1):
    plot_images(img_batch, mask_batch)

# %% [markdown]
# # Model

# %%
#pip install keras==3.11.2 tensorflow==2.19.0

# %%
import tensorflow as tf
print(tf.__version__)
import keras as k
print(k.__version__)
# Out:
# 2.19.0
# 3.11.2

# %%
model = SegFormer_B2(input_shape = (256,256,3), num_classes = 34)
# Out:
# WARNING:tensorflow:From c:\Python312\Lib\site-packages\keras\src\backend\tensorflow\core.py:232: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.

# %%
model.compile(optimizer='adam', 
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])

# %%
steps_per_epoch = 2975 // 8
validation_steps = 500 // 8

# %%
history = model.fit(train_ds, steps_per_epoch=steps_per_epoch, validation_data=val_ds, validation_steps=validation_steps, epochs=20)
# Out:
# Epoch 1/20
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 2324s 6s/step - accuracy: 0.8130 - loss: 0.6785 - val_accuracy: 0.7315 - val_loss: 1.0882
# Epoch 2/20
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 2318s 6s/step - accuracy: 0.8198 - loss: 0.6547 - val_accuracy: 0.7318 - val_loss: 1.0704
# Epoch 3/20
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 2312s 6s/step - accuracy: 0.8236 - loss: 0.6412 - val_accuracy: 0.7282 - val_loss: 1.0578
# Epoch 4/20
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 2318s 6s/step - accuracy: 0.8267 - loss: 0.6281 - val_accuracy: 0.7452 - val_loss: 1.0045
# Epoch 5/20
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 2312s 6s/step - accuracy: 0.8299 - loss: 0.6159 - val_accuracy: 0.7491 - val_loss: 0.9862
# Epoch 6/20
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 2326s 6s/step - accuracy: 0.8329 - loss: 0.6077 - val_accuracy: 0.7341 - val_loss: 1.0501
# Epoch 7/20
# 371/371 ━━━━━━━━━━━━━━━━━━━━ 2329s 6s/step - accuracy: 0.8371 - loss: 0.5927 - val_accuracy: 0.7211 - val_loss: 1.0690
# Epoch 8/20
# ...

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
input_shape = (256, 256, 3)  
num_classes = 34              
model = SegFormer_B2(input_shape=input_shape, num_classes=num_classes)
model.load_weights("/Users/vinithlankireddy/Projects/LLMs/Segfromer/SegFormer-tf-main/Notebook/segformer_b2-20_weights.weights.h5")

# %%
num = 3

for img, label in val_ds.take(1):
    pred_label = model.predict(img)
    pred_label = tf.argmax(pred_label, axis=-1)
    pred_label = pred_label[..., tf.newaxis]
    
    plt.figure(figsize=(10, 10))
    for i in range(num):
        plt.subplot(num, 3, i*num+1)
        plt.imshow(tf.keras.preprocessing.image.array_to_img(img[i]))
        plt.subplot(num, 3, i*num+2)
        plt.imshow(tf.keras.preprocessing.image.array_to_img(label[i]))
        plt.subplot(num, 3, i*num+3)
        plt.imshow(tf.keras.preprocessing.image.array_to_img(pred_label[i]))
# Out:
# 2025-11-07 06:28:46.665078: W tensorflow/core/kernels/data/cache_dataset_ops.cc:916] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset  will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step

# %%
# Save the entire model to a file
# model.save('segformer_b2-20.keras')

# %%
# Save only the model's weights
# model.save_weights('segformer_b2-20_weights.weights.h5')

# %%
# img_path = "/Users/vinithlankireddy/Projects/LLMs/Segfromer/SegFormer-tf-main/Cityspaces/images/val/frankfurt/frankfurt_000000_002963_leftImg8bit.png"
# img_path = "/Users/vinithlankireddy/Projects/LLMs/Segfromer/SegFormer-tf-main/Cityspaces/images/val/lindau/lindau_000001_000019_leftImg8bit.png"
# img_path ="/Users/vinithlankireddy/Projects/LLMs/Segfromer/SegFormer-tf-main/Cityspaces/images/train/strasbourg/strasbourg_000000_002183_leftImg8bit.png"
# img_path = "/Users/vinithlankireddy/Projects/LLMs/Segfromer/SegFormer-tf-main/Cityspaces/images/val/lindau/lindau_000006_000019_leftImg8bit.png"
img_path = "/Users/vinithlankireddy/Projects/LLMs/Segfromer/SegFormer-tf-main/Cityspaces/images/train/bochum/bochum_000000_000313_leftImg8bit.png"
# img_path = "/Users/vinithlankireddy/Projects/LLMs/Segfromer/SegFormer-tf-main/Cityspaces/images/val/lindau/lindau_000003_000019_leftImg8bit.png"
img_path = "/Users/vinithlankireddy/Projects/LLMs/Segfromer/SegFormer-tf-main/Cityspaces/images/val/lindau/lindau_000054_000019_leftImg8bit.png"
img_path = "/Users/vinithlankireddy/Projects/LLMs/Segfromer/SegFormer-tf-main/Cityspaces/images/train/strasbourg/strasbourg_000001_065214_leftImg8bit.png"

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# --- Load your own image ---
# img_path = "/Users/vinithlankireddy/Projects/LLMs/Segfromer/SegFormer-tf-main/Cityspaces/images/train/strasbourg/strasbourg_000001_061472_leftImg8bit.png"
img_path = "/Users/vinithlankireddy/Projects/LLMs/Segfromer/SegFormer-tf-main/Cityspaces/images/val/lindau/lindau_000054_000019_leftImg8bit.png"


img = Image.open(img_path).convert("RGB")
img = img.resize((256, 256))
img_array = np.array(img) / 255.0
img_tensor = np.expand_dims(img_array, 0)

# --- Predict ---
pred = model.predict(img_tensor)
pred_label = tf.argmax(pred[0], axis=-1)
pred_label = pred_label[..., tf.newaxis]

# --- Visualize single image ---
plt.figure(figsize=(10, 5))
plt.subplot(1, 3, 1)
plt.imshow(img)
plt.title("Input Image")
plt.axis("off")

plt.subplot(1, 3, 2)
plt.imshow(pred_label[..., 0], tf.newaxis)
plt.title("Predicted Segmentation")
plt.axis("off")

plt.subplot(1, 3, 3)
overlay = 0.6 * np.array(img)/255.0 + 0.4 * plt.cm.tab20(pred_label[..., 0]/np.max(pred_label))[..., :3]
plt.imshow(overlay)
plt.title("Overlay")
plt.axis("off")

plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step
